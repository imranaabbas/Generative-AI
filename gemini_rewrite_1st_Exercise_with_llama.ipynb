# %% [markdown]
# # 🐐 LLaMA Text Transformations (CPU, Colab)

# %%
# !pip install -q llama-cpp-python wget

# %%
import wget

model_url = "https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF/resolve/main/Llama-2-7B-Chat.gguf"
fname = model_url.split("/")[-1]
print("Downloading model…")
wget.download(model_url)
print("\nSaved:", fname)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import wget
#       3 model_url = "https://huggingface.co/TheBloke/Llama-2-7B-Chat-GGUF/resolve/main/Llama-2-7B-Chat.gguf"
#       4 fname = model_url.split("/")[-1]
#
# ModuleNotFoundError: No module named 'wget'

# %%
from llama_cpp import Llama
from textwrap import dedent

llm = Llama(model_path="Llama-2-7B-Chat.gguf", n_ctx=4096, n_threads=8)

input_text = dedent("""
Artificial Intelligence refers to machines or systems that perform tasks requiring human intelligence,
such as learning, reasoning, decision-making, and perception. Modern AI is increasingly used in
healthcare, finance, education, and creative industries.
""").strip()

print("Input Text:\n", input_text)

# %%
prompts = {
    "summary": f"Summarize:\n\n{input_text}",
    "kids_version": f"Explain to a 10-year-old:\n\n{input_text}",
    "business_version": f"Rewrite for a business audience:\n\n{input_text}",
    "tamil_version": f"Translate to Tamil:\n\n{input_text}",
    "bullet_points": f"Bullet points:\n\n{input_text}",
}

outputs = {}
for key, prompt in prompts.items():
    print(f"\n=== {key.upper()} ===")
    resp = llm(prompt, max_tokens=220, temperature=0.7)
    txt = resp["choices"][0]["text"].strip()
    outputs[key] = txt
    print(txt)

# %%
from IPython.display import Markdown, display
print("\n## Final Outputs")
for key, text in outputs.items():
    display(Markdown(f"### {key.replace('_',' ').title()}\n{text}"))
