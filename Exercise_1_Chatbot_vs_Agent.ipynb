# %% [markdown]
# # Exercise 1: Chatbot vs Agent\n\nThis notebook demonstrates the **conceptual difference between a Chatbot and an Agent**.\n\n**Objective:** Understand why Agentic AI is different from prompt-based chatbots.

# %% [markdown]
# # Exercise 1: Chatbot vs Agent
#
# This notebook demonstrates the **conceptual difference between a Chatbot and an Agent**.
#
# **Objective:** Understand why Agentic AI is different from prompt-based chatbots.

# %% [markdown]
# ## Chatbot Example
#
# This section presents a simple chatbot implementation. Chatbots typically respond directly to user input based on pre-defined rules or patterns, without maintaining a long-term plan or performing complex actions.

# %%
print('=== CHATBOT MODE ===')

def chatbot(user_input):
    """Simulates a basic chatbot response."""
    return f"Chatbot response to '{user_input}': Here is some information."

print(chatbot('Plan my semester'))
# Out:
# === CHATBOT MODE ===
# Chatbot response to 'Plan my semester': Here is some information.

# %% [markdown]
# ## Agent Example
#
# This section demonstrates an AI agent. Unlike a chatbot, an agent can break down a complex goal into a series of steps, execute those steps, and often interact with external tools or systems to achieve the goal.

# %%
print('\n=== AGENT MODE ===')

def agent(user_goal):
    """Simulates an AI agent breaking down a goal into steps."""
    steps = [
        'Understand goal',
        'Check academic calendar',
        'Identify required courses',
        'Create semester plan',
        'Ask user for confirmation'
    ]
    print(f'Agent received goal: {user_goal}')
    for step in steps:
        print(f'Agent step: {step}')
    return 'Agent completed planning with actions.'

print(agent('Plan my semester'))
# Out:
# === AGENT MODE ===
# Agent received goal: Plan my semester
# Agent step: Understand goal
# Agent step: Check academic calendar
# Agent step: Identify required courses
# Agent step: Create semester plan
# Agent step: Ask user for confirmation
# Agent completed planning with actions.

# %%
# Chatbot example\nprint("=== CHATBOT MODE ===")\n\ndef chatbot(user_input):\n    return f"Chatbot response to '{user_input}': Here is some information."\n\nprint(chatbot("Plan my semester"))

# %%
# Agent example\nprint("\n=== AGENT MODE ===")\n\ndef agent(user_goal):\n    steps = [\n        "Understand goal",\n        "Check academic calendar",\n        "Identify required courses",\n        "Create semester plan",\n        "Ask user for confirmation"\n    ]\n    print(f"Agent received goal: {user_goal}")\n    for step in steps:\n        print(f"Agent step: {step}")\n    return "Agent completed planning with actions."\n\nprint(agent("Plan my semester"))

# %% [markdown]
# ## Reflection Questions\n- How is the agent different from the chatbot?\n- Where would tools and memory fit in the agent flow?\n- Why is this approach useful for real-world systems?
