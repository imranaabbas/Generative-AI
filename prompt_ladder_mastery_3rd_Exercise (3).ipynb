# %% [markdown]
# # Prompt Ladder / Prompt Mastery — Gemini Hands‑On Exercise
# This lab demonstrates how to progressively control an LLM through structured prompting.

# %%
#Install Gemini SDK!
# !pip install google-generativeai --upgrade
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.29.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.188.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.47.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.12.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.27.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2026.1.4)

# %%
import google.generativeai as genai
print('Gemini SDK imported.')
# Out:
# Gemini SDK imported.
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
# Configure API Key
# IMPORTANT: Replace 'YOUR_GEMINI_API_KEY' with your actual Gemini API key.
# For better security, consider storing your API key in Colab Secrets.
API_KEY='GEMINI_API_KEY'
genai.configure(api_key=API_KEY)
print('API configured.')
# Out:
# API configured.

# %%
# Initialize model
model=genai.GenerativeModel('gemini-2.5-flash')
print('Model loaded: gemini-2.5-flash')
# Out:
# Model loaded: gemini-2.5-flash

# %% [markdown]
# ## 1. Zero‑Shot Prompting

# %%
model=genai.GenerativeModel('gemini-2.5-flash') # Ensure model is initialized
print('Model loaded: gemini-2.5-flash')

print('\n=== ZERO-SHOT ===')
prompt='Explain Neural Networks.' # Define the zero-shot prompt
print('Prompt:', prompt)
resp=model.generate_content(prompt) # Generate content using the defined prompt
print('Response:')
print(resp.text)
# Out:
# Model loaded: gemini-2.5-flash
#
# === ZERO-SHOT ===
# Prompt: Explain Neural Networks.
# Response:
# Imagine a Neural Network as a simplified, digital brain designed to recognize patterns and make decisions in a way that mimics how our brains *might* work. It's the core technology behind many of today's impressive AI advancements, like recognizing faces, understanding speech, or driving autonomous cars.
#
# Let's break it down:
#
# ---
#
# ### The Core Idea: Learning from Examples
#
# At its heart, a Neural Network learns from data by seeing many examples, much like a child learns what a "cat" is by seeing various cats. Instead of being explicitly programmed with rules (e.g., "a cat has pointy ears, whiskers, and meows"), it figures out those rules itself by observing patterns in the data.
#
# ---
#
# ### The Basic Building Block: The Neuron (or Node)
#
# Think of a neuron as a tiny decision-making unit.
#
# 1.  **Inputs:** It receives several pieces of information (inputs) from other neurons or from the raw data itself.
# 2.  **Weights:** Each input is assigned a "weight" – a number that indicates how important that input is. A higher weight means that input has a stronger influence on the neuron's decision.
# 3.  **Bias:** An additional value called "bias" is added. Think of it as a base level of activation, allowing the neuron to activate even if all its inputs are zero, or to make it harder to activate.
# 4.  **Summation:** The neuron multiplies each input by its weight, adds them all up, and then adds the bias.
# 5.  **Activation Function:** This sum then passes through an "activation function." This is a mathematical function that decides whether the neuron should "fire" (become active and pass information along) and how strongly. It introduces non-linearity, which is crucial for the network to learn complex patterns. Common activation functions include ReLU (Rectified Linear Unit), Sigmoid, or Tanh.
# 6.  **Output:** The result of the activation function is the neuron's output, which is then passed on as an input to other neurons.
#
# ---
#
# ### How Neurons Connect: Layers
#
# Neurons are organized into layers:
#
# 1.  **Input Layer:** This is where the raw data enters the network. Each neuron in this layer typically represents a feature of the input (e.g., a pixel in an image, a word in a sentence, a numerical value).
# 2.  **Hidden Layers:** Between the input and output layers are one or more "hidden" layers. These layers are where the network performs its complex computations and extracts increasingly abstract features from the data. A network with many hidden layers is called a **Deep Neural Network**, which is the basis of "Deep Learning."
# 3.  **Output Layer:** This layer produces the final result of the network. The number of neurons here depends on the task (e.g., one neuron for a yes/no prediction, multiple neurons for classifying an image into one of several categories).
#
# ![Neural Network Diagram](https://upload.wikimedia.org/wikipedia/commons/4/46/Colored_neural_network.svg)
# *A simple diagram showing input, hidden, and output layers.*
#
# ---
#
# ### How Information Flows: Forward Propagation
#
# When you feed data into a Neural Network (e.g., an image of a cat), the information flows through the network in one direction:
#
# 1.  The input layer receives the data.
# 2.  Each neuron in the first hidden layer processes its inputs (multiplies by weights, adds bias, applies activation function) and generates an output.
# 3.  These outputs become the inputs for the next hidden layer, and so on.
# 4.  Finally, the output layer produces the network's prediction (e.g., "It's a cat!").
#
# This entire process of calculating predictions is called **Forward Propagation**.
#
# ---
#
# ### How Neural Networks Learn: Backpropagation and Optimization
#
# This is the truly ingenious part:
#
# 1.  **Make a Prediction:** The network performs forward propagation and makes a prediction.
# 2.  **Measure the Error (Loss Function):** The network then compares its prediction with the actual correct answer (the "ground truth"). It uses a **Loss Function** (or Cost Function) to calculate how far off its prediction was. A higher loss means a worse prediction.
# 3.  **Adjust Weights (Backpropagation):** This is where **Backpropagation** comes in. The error is "propagated backward" through the network, from the output layer to the input layer. During this process, the network calculates how much each individual weight and bias contributed to the overall error. It essentially figures out who was "most responsible" for the mistake.
# 4.  **Optimization (Gradient Descent):** Based on these calculated contributions (called "gradients"), an **Optimizer** (like Gradient Descent) adjusts the weights and biases slightly. The goal is to nudge these values in a direction that would *reduce* the loss next time. Think of it like a hiker trying to get down a hill in a fog – they take small steps in the steepest downward direction.
# 5.  **Iterate:** This entire process (forward propagation, calculating loss, backpropagation, updating weights) is repeated thousands or millions of times, with different batches of data. With each iteration, the network's weights and biases are refined, and its predictions become more accurate.
#
# ---
#
# ### Why are Neural Networks So Powerful?
#
# *   **Pattern Recognition:** Excellent at finding complex, non-linear patterns in data that humans or traditional algorithms might miss.
# *   **Feature Learning:** Hidden layers can automatically learn and extract relevant features from raw data, rather than requiring humans to manually engineer them.
# *   **Adaptability:** They can be trained for a wide variety of tasks by simply changing the training data and tweaking their architecture.
# *   **Scalability:** With enough data and computational power, they can often outperform other methods on complex problems.
#
# ---
#
# ### Applications
#
# Neural Networks are used in:
#
# *   **Computer Vision:** Image recognition, object detection, facial recognition.
# *   **Natural Language Processing (NLP):** Speech recognition, machine translation, sentiment analysis, chatbots, text generation.
# *   **Recommendation Systems:** Suggesting products, movies, or music.
# *   **Medical Diagnosis:** Identifying diseases from images (X-rays, MRIs).
# *   **Autonomous Vehicles:** Helping cars "see" and understand their environment.
# *   **Financial Forecasting:** Predicting stock prices or market trends.
#
# ---
#
# ### Limitations
#
# *   **Data Hungry:** They require vast amounts of data to train effectively.
# *   **Computationally Intensive:** Training large networks can require significant computing power and time.
# *   **"Black Box":** It can be difficult to understand *why* a neural network made a particular decision, leading to issues with interpretability and trustworthiness in critical applications.
# *   **Bias:** If trained on biased data, the network will learn and perpetuate those biases.
#
# ---
#
# In essence, a Neural Network is a powerful, adaptive system that learns to map inputs to outputs by iteratively adjusting the strengths of connections (weights) between its simple processing units (neurons), driven by the goal of minimizing prediction errors.

# %% [markdown]
# ## 2. Few‑Shot Prompting

# %%
print('\n=== FEW-SHOT ===')
prompt="""Explain the following in simple terms:Example:Concept: Machine LearningExplanation: Machine learning lets computers learn from data.Now explain:Concept: Neural NetworksExplanation:""" # Define the few-shot prompt with an example
print('Prompt:',prompt)
resp=model.generate_content(prompt) # Generate content based on the few-shot example
print(resp.text)
# Out:
# === FEW-SHOT ===
# Prompt: Explain the following in simple terms:Example:Concept: Machine LearningExplanation: Machine learning lets computers learn from data.Now explain:Concept: Neural NetworksExplanation:
# Concept: Neural Networks
# Explanation: Neural networks let computers learn by mimicking a simplified human brain. They use layers of interconnected "neurons" to find complex patterns in data, helping them recognize things or make predictions.

# %% [markdown]
# ## 3. Role‑Based Prompting

# %%
print('\n=== ROLE-BASED ===')
prompt=f"Act as a university professor. Explain Neural Networks to first-year engineering students." # Define the role-based prompt
print('Prompt:',prompt)
resp=model.generate_content(prompt) # Generate content with the specified persona/role
print(resp.text)
# Out:
# === ROLE-BASED ===
# Prompt: Act as a university professor. Explain Neural Networks to first-year engineering students.
# Alright, settle in everyone. Good morning!
#
# Today, we're going to dive into one of the most exciting and transformative technologies of our time: **Neural Networks**. You've interacted with them almost daily, probably without even realizing it. When your phone recognizes your face, when Netflix recommends a show, when Siri understands your question, or when a self-driving car navigates traffic – you're seeing neural networks in action.
#
# My goal today is not to turn you into an AI expert overnight, but to demystify them, to explain what they are, how they broadly work, and why they're such powerful tools for engineers like yourselves.
#
# ### The Big Idea: Learning from Data
#
# At its heart, a neural network is a computational model, loosely inspired by the human brain, that excels at finding patterns and making decisions from vast amounts of data where traditional, rule-based programming struggles.
#
# Think about it: how would you write a program to identify a cat in an image? You could try to list rules: "It has two ears, four legs, a tail, whiskers..." But what about a cat lying down? Or a cat seen from behind? Or a cartoon cat? The rules quickly become overwhelmingly complex and insufficient.
#
# Neural networks offer a different approach: instead of giving it rules, we give it *examples*. Thousands, millions of examples of "cat" and "not-cat" images, and let it figure out the rules for itself.
#
# ### Analogy Time: The Pop-Up Restaurant Critic
#
# Let's use an analogy to build our intuition. Imagine you're building a sophisticated system to predict if a new, pop-up restaurant will be a hit or a flop.
#
# 1.  **Inputs:** You gather information: the chef's reputation (1-10), the average price of a dish ($10-$100), the type of cuisine (e.g., Italian=1, Mexican=2, Fusion=3), the Instagram buzz (1-10), etc. These are your **input data points**.
#
# 2.  **The "Critics" (Neurons):** Inside your system, you have a panel of highly specialized "critics."
#     *   One critic only cares about **taste**.
#     *   Another cares about **ambiance**.
#     *   Another cares about **price-value**.
#     *   Another about the **innovation of the menu**.
#
#     Each of these critics receives all the input information, but they process it differently. They give different *importance* to different inputs.
#
# 3.  **The "Weight" of Opinion:**
#     *   The "taste" critic might give a *very high importance* (or **weight**) to the chef's reputation and less importance to the price.
#     *   The "price-value" critic might give a *very high weight* to the average price and less to Instagram buzz.
#     *   These **weights** are crucial. They represent how much influence an input has on a critic's opinion.
#     *   Each critic also has a **bias** – kind of an inherent leaning. Some critics are naturally more optimistic, others more cynical, regardless of the inputs.
#
# 4.  **Forming an Opinion (Activation Function):**
#     *   Each critic takes all the inputs, multiplies them by their specific weights, sums them up, and then adds their bias.
#     *   Then, they apply a "threshold" or a "squashing function." If the combined "score" is high enough, they "speak up" strongly (e.g., "This restaurant is a definite hit on taste!"). If it's low, they remain quiet or offer a mild opinion. This thresholding process is called the **activation function**. It determines if a neuron "fires" or passes information onward.
#
# 5.  **The Committee (Layers):**
#     *   Now, these individual critics don't just output their opinions directly to you. Their opinions might feed into *another layer* of critics.
#     *   Perhaps there's a "local food blogger" critic who takes the opinions of the "taste" and "ambiance" critics and forms a more refined, higher-level opinion.
#     *   This layering allows the system to recognize increasingly complex patterns. The first layer might detect simple features (is it expensive? is the chef famous?). The next layer combines these simple features into more abstract concepts (is it a fine dining experience? is it a trendy spot?). These are your **hidden layers**.
#
# 6.  **The Final Verdict (Output Layer):**
#     *   Finally, the opinions from the last layer of critics feed into a single, final "Chief Reviewer" who takes all these processed opinions and produces a single output: "This restaurant will be a **HIT**" or "This restaurant will be a **FLOP**." This is your **output layer**.
#
# ### How Does It "Learn"? The Magic of Training
#
# The power of neural networks isn't just in their structure, but in their ability to *learn*.
#
# 1.  **Training Data:** You start by giving your system a huge dataset of *past* pop-up restaurants, where you already know whether they were a hit or a flop.
# 2.  **Prediction:** You feed the data for a past restaurant into your network. It makes a prediction (e.g., "This will be a HIT").
# 3.  **Error Calculation:** You compare the network's prediction to the *actual* outcome. Was it right? If it predicted "HIT" but the restaurant was a "FLOP," it made an error.
# 4.  **Adjusting the Weights (Backpropagation):** This is the crucial part. The network figures out *which critics were wrong* and *how much* their weights and biases contributed to the error. It then slightly adjusts those weights and biases to make the prediction more accurate next time. This process of error correction, propagating backward through the network, is called **backpropagation**.
# 5.  **Iteration:** You repeat this process *thousands or millions of times* with all your training data. Each time, the weights and biases are slightly adjusted, slowly making the network "smarter" and its predictions more accurate. It's like a sculptor refining their work, gradually chipping away until the perfect form emerges.
#
# ### Why Are They So Powerful for Engineers?
#
# 1.  **Pattern Recognition:** They excel at tasks where patterns are intricate and hard to explicitly define (like recognizing faces, speech, or subtle defects in materials).
# 2.  **Adaptability:** Once trained, they can generalize to new, unseen data, making predictions on information they haven't encountered before.
# 3.  **Scalability:** With enough data and computational power, they can tackle incredibly complex problems.
# 4.  **Feature Learning:** Unlike traditional methods where you might have to hand-engineer features (e.g., "count the number of corners" in an image), neural networks can learn relevant features directly from the raw data.
#
# ### Real-World Engineering Applications:
#
# *   **Computer Vision:** Quality control in manufacturing (detecting flaws), autonomous vehicle navigation, medical image analysis (diagnosing diseases from X-rays, MRIs).
# *   **Natural Language Processing:** Building better chatbots for customer service, language translation, sentiment analysis of social media feeds.
# *   **Robotics:** Allowing robots to learn complex manipulation tasks, navigate dynamic environments.
# *   **Predictive Maintenance:** Analyzing sensor data from machinery to predict when parts are likely to fail, optimizing maintenance schedules.
# *   **Materials Science:** Discovering new materials with desired properties.
# *   **Smart Grids:** Optimizing energy distribution and predicting demand.
#
# ### Challenges and Considerations
#
# While powerful, neural networks aren't magic:
#
# *   **Data Hunger:** They often require vast amounts of high-quality data to train effectively.
# *   **Computational Cost:** Training large networks can be incredibly resource-intensive, requiring specialized hardware (GPUs).
# *   **"Black Box" Problem:** Sometimes, it's hard to understand *why* a neural network made a particular decision. This lack of interpretability can be a concern in critical applications like healthcare or law.
# *   **Bias:** If the training data contains biases (e.g., images of mostly one demographic), the network will learn and perpetuate those biases. This is a significant ethical consideration for engineers.
#
# ### Looking Ahead
#
# As first-year engineers, understanding these fundamentals is crucial. The field of neural networks, particularly "Deep Learning" (which just means neural networks with *many* hidden layers), is rapidly evolving. You'll encounter more specialized types like Convolutional Neural Networks (for images) and Recurrent Neural Networks (for sequences like text) in your later courses.
#
# But for now, remember the core idea: networks of simple processing units, learning by adjusting their connections based on data, to solve problems that were once considered impossible for computers.
#
# This is the frontier of engineering, and you are stepping right into it. Think critically, ask questions, and embrace the challenge!
#
# Now, let's open it up for any questions you might have. What sparked your curiosity?

# %% [markdown]
# ## 4. Chain‑of‑Thought Prompting

# %%
print('\n=== CHAIN-OF-THOUGHT ===')
prompt="""Explain Neural Networks step-by-step:1. Start with intuition2. Define components3. Explain how they learn4. Give a real-world example""" # Define the chain-of-thought prompt with structured steps
print('Prompt:',prompt)
resp=model.generate_content(prompt) # Generate content by following the given steps
print(resp.text)
# Out:
# === CHAIN-OF-THOUGHT ===
# Prompt: Explain Neural Networks step-by-step:1. Start with intuition2. Define components3. Explain how they learn4. Give a real-world example
# Let's break down Neural Networks step-by-step, starting with the big picture and then diving into the details.
#
# ---
#
# ### 1. Intuition: The Brain-Inspired Problem Solver
#
# Imagine a simplified, digital "brain" designed to solve specific problems by learning from examples, much like humans do. That's essentially what a neural network is.
#
# *   **Core Idea:** It's a system that takes in information, processes it through multiple interconnected "neurons," and then makes a decision or prediction.
# *   **What they do:** They are incredibly good at finding complex patterns and relationships in data that are too subtle or complicated for humans to program manually.
# *   **Analogy:** Think of trying to teach a child to identify a cat. You don't give them a list of rigid rules ("if it has pointy ears AND whiskers AND a tail..."). Instead, you show them many pictures of cats and non-cats, and over time, their brain *learns* what distinguishes a cat. A neural network learns in a very similar, albeit mathematical, way, by adjusting its internal "understanding" based on examples.
# *   **Goal:** To transform raw input data into meaningful outputs by discovering underlying features and relationships within that data.
#
# ---
#
# ### 2. Defining the Components: The Building Blocks
#
# Neural networks are made up of several key parts working together:
#
# 1.  **Neurons (or Nodes):**
#     *   **What:** These are the fundamental processing units, like a single brain cell.
#     *   **How they work:** Each neuron receives inputs from other neurons (or from the initial data), performs a simple calculation on them, and then passes the result to the next neurons.
#
# 2.  **Layers:**
#     *   Neurons are organized into layers.
#     *   **Input Layer:** The first layer. Each neuron here receives a single feature from your input data (e.g., one pixel value from an image, one numerical feature from a dataset).
#     *   **Hidden Layers:** One or more layers between the input and output. This is where the network learns increasingly complex patterns and representations of the data. The more hidden layers, the deeper the network, often allowing it to learn more intricate relationships.
#     *   **Output Layer:** The final layer. Its neurons produce the network's final prediction or decision (e.g., "cat" or "dog," a specific number, etc.).
#
# 3.  **Connections (Synapses):**
#     *   **What:** Information flows between neurons through these connections. In a "fully connected" network, every neuron in one layer is connected to every neuron in the next layer.
#
# 4.  **Weights:**
#     *   **What:** Each connection has an associated numerical value called a "weight."
#     *   **Role:** Weights determine the *strength* or *importance* of a particular input connection. A higher weight means that input has a stronger influence on the receiving neuron.
#
# 5.  **Biases:**
#     *   **What:** Each neuron also has an associated numerical value called a "bias."
#     *   **Role:** Biases allow a neuron to activate even if all its inputs are zero, or to remain inactive even if it has strong inputs. They essentially shift the activation function, giving the neuron more flexibility to adjust its output independently of its inputs. Think of it as a personal "threshold" for the neuron to activate.
#
# 6.  **Activation Function:**
#     *   **What:** A mathematical function applied to the output of a neuron.
#     *   **Role:** It decides whether a neuron should "fire" (be activated) and pass information to the next layer. Crucially, it introduces **non-linearity** into the network. Without activation functions, a neural network would just be a simple linear model, unable to learn anything more complex than a basic straight line. Common examples include ReLU, Sigmoid, and Tanh.
#
# ---
#
# ### 3. How They Learn: The Process of Backpropagation
#
# Learning in a neural network is an iterative process of refining its weights and biases until it can make accurate predictions. This process is primarily driven by something called **Backpropagation**.
#
# 1.  **Initialization:**
#     *   Initially, all the weights and biases in the network are set to random, small values. At this stage, the network is essentially "ignorant" and will make very poor predictions.
#
# 2.  **Forward Pass (Making a Prediction):**
#     *   Input data (e.g., an image of a cat) is fed into the input layer.
#     *   Each neuron in the input layer passes its value, multiplied by its connection weight, to the neurons in the first hidden layer.
#     *   Each neuron in a hidden layer:
#         *   Receives inputs from the previous layer, each multiplied by its respective weight.
#         *   Sums up these weighted inputs, and adds its bias.
#         *   Applies its activation function to this sum.
#         *   Passes the result to the next layer.
#     *   This process continues layer by layer until the output layer produces a final prediction (e.g., "it's a dog" with 80% probability, "it's a cat" with 20% probability).
#
# 3.  **Calculate the Error (Loss Function):**
#     *   The network's prediction is compared to the *actual* correct answer (the "ground truth" – in this case, it was a cat).
#     *   A **loss function** (e.g., Mean Squared Error, Cross-Entropy) calculates how "wrong" the prediction was. A higher loss means a greater error. If the network predicted "dog" for a "cat" image, the loss will be high.
#
# 4.  **Backward Pass (Backpropagation - The Learning Step):**
#     *   This is the core of learning. The error calculated in step 3 is propagated *backward* through the network, from the output layer to the input layer.
#     *   **Gradient Calculation:** For each weight and bias in the network, backpropagation calculates how much it contributed to the overall error. This "contribution" is called the **gradient**. Think of it as finding out which knobs (weights/biases) need to be turned and by how much to reduce the error.
#     *   **Weight & Bias Update (Optimization):** An **optimizer** (like Gradient Descent) uses these gradients to adjust the weights and biases. The goal is to slightly change each weight and bias in a direction that will reduce the loss for the next forward pass.
#         *   `New Weight = Old Weight - (Learning Rate * Gradient)`
#         *   The "learning rate" is a small value that controls how big a step the optimizer takes with each adjustment.
#
# 5.  **Iteration (Epochs):**
#     *   Steps 2-4 are repeated thousands or even millions of times, using many different examples from the training data. Each full pass through the entire training dataset is called an "epoch."
#     *   With each iteration, the weights and biases are incrementally adjusted, causing the network's predictions to become more accurate and the overall loss to decrease. The network learns by continuously trying to minimize its error.
#
# ---
#
# ### 4. Real-World Example: Image Classification (Is it a Cat or a Dog?)
#
# Let's use our cat/dog example to illustrate the process:
#
# 1.  **Problem:** Build a neural network that can classify an image as either a "cat" or a "dog."
#
# 2.  **Data Preparation:**
#     *   You gather a large dataset of images, each accurately labeled as either "cat" or "dog."
#     *   Each image is converted into a numerical format. For instance, a 100x100 pixel color image would be represented by 100 * 100 * 3 (for Red, Green, Blue channels) = 30,000 numerical values.
#
# 3.  **Input Layer:**
#     *   Each of these 30,000 pixel values is fed as a separate input into a neuron in the **Input Layer** of the network.
#
# 4.  **Hidden Layers (Feature Extraction):**
#     *   **Early Hidden Layers:** Neurons in the first few hidden layers might learn to detect very simple, generic features like **edges**, **lines**, or **corners** at different orientations and locations within the image.
#     *   **Deeper Hidden Layers:** Subsequent hidden layers combine these simpler features to form increasingly complex and abstract features. They might learn to recognize shapes like **eyes**, **ears**, **snouts**, or **fur textures**. The network *discovers* these features itself, purely from the data, without being explicitly programmed. It learns which combinations of edges usually form an ear, and which combination of shapes tends to be a nose.
#
# 5.  **Output Layer (Classification):**
#     *   The final hidden layer feeds into the **Output Layer**.
#     *   In this case, the output layer might have two neurons: one representing "cat" and one representing "dog."
#     *   Each neuron will output a probability score (e.g., if the network sees a cat image: "cat: 0.95, dog: 0.05"). This indicates the network's confidence in the image being a cat (95%) versus a dog (5%).
#
# 6.  **Learning in Action (Backpropagation):**
#     *   **Initial Stage:** When you first start training, the network's weights are random. It might see a cat image and randomly guess "dog" with 60% probability.
#     *   **Error Calculation:** The **loss function** detects a significant error (predicted "dog" for a "cat").
#     *   **Backward Pass:** Backpropagation identifies which weights and biases contributed to this wrong prediction. It calculates the gradients for all parameters.
#     *   **Weight Adjustment:** The optimizer uses these gradients to slightly adjust all the weights and biases. It will subtly decrease the influence of connections that led to the "dog" prediction and increase the influence of connections that should have activated "cat" features.
#     *   **Iteration:** This process is repeated for thousands or millions of cat and dog images. Over time, the network gradually refines its internal features and decision boundaries. It gets better and better at recognizing the unique visual patterns that differentiate cats from dogs, minimizing its prediction errors until it can accurately classify new, unseen images.
#
# In essence, neural networks learn to create a complex internal model of the world (or at least the data you show them) by continuously adjusting their parameters based on their prediction errors.

# %% [markdown]
# ## 5. Self‑Critique / Revision Prompting

# %%
print('\n=== SELF-CRITIQUE ===')
prompt=f"""Explain Neural Networks in 5 sentences.Then:- Identify confusing parts- Rewrite them more clearly""" # Define the self-critique prompt, asking the model to evaluate and improve its own output
print('Prompt:',prompt)
resp=model.generate_content(prompt) # Generate content and then critique/revise it
print(resp.text)
# Out:
# === SELF-CRITIQUE ===
# Prompt: Explain Neural Networks in 5 sentences.Then:- Identify confusing parts- Rewrite them more clearly
# Here's an explanation of Neural Networks in 5 sentences:
#
# Neural networks are computer systems designed to mimic how the human brain processes information. They consist of interconnected "neurons" organized into layers: an input layer, one or more hidden layers, and an output layer. Information passes between neurons through connections, each with a numerical 'weight' that either strengthens or weakens the signal. Inside each neuron, a simple calculation happens, and an 'activation function' decides whether to pass the signal forward, introducing complexity. By processing vast amounts of training data, the network automatically adjusts these weights to learn patterns and make predictions or classifications.
#
# ---
#
# ### Identifying Confusing Parts & Rewriting Them More Clearly
#
# The two most potentially confusing parts in the initial explanation for a beginner are:
#
# 1.  **"each with a numerical 'weight' that either strengthens or weakens the signal."**
# 2.  **"an 'activation function' decides whether to pass the signal forward, introducing complexity."**
#
# Let's rewrite these parts for greater clarity, embedding them back into the explanation.
#
# ---
#
# **Original Confusing Parts (and why they might be confusing):**
#
# 1.  **"each with a numerical 'weight' that either strengthens or weakens the signal."**
#     *   **Why confusing?** While "strengthens or weakens" is a good start, it doesn't quite explain *how* that happens or its direct impact. What does it mean for the *information*? Is it like a volume knob, or a filter?
#
# 2.  **"an 'activation function' decides whether to pass the signal forward, introducing complexity."**
#     *   **Why confusing?** "Activation function" is jargon. "Decides whether to pass the signal forward" is okay, but "introducing complexity" is abstract. What kind of complexity? Why is it needed? It's the core "thinking" part of a neuron but described vaguely.
#
# ---
#
# **Rewritten Explanation (with clarified parts):**
#
# Neural networks are computer systems designed to mimic how the human brain processes information. They consist of interconnected "neurons" organized into layers: an input layer, one or more hidden layers, and an output layer. **Information flows from neuron to neuron across connections, and each connection has a numerical 'weight' that acts like a multiplier, making some pieces of information more impactful or less impactful on the next neuron.** Inside each neuron, the incoming information is summed up, and **an 'activation function' then processes this sum to decide if the neuron should 'fire' and send a signal forward, much like a filter deciding what information is important enough to pass on, allowing the network to learn non-linear, complex relationships.** By processing vast amounts of training data, the network automatically adjusts these weights (and other parameters) to learn patterns and make predictions or classifications.
#
# ---
#
# **Explanation of Clarity Improvements:**
#
# 1.  **Weights:**
#     *   Changed "strengthens or weakens the signal" to "acts like a multiplier, making some pieces of information more impactful or less impactful on the next neuron."
#     *   This provides a clearer mechanism (a multiplier) and directly links it to the *impact* on the subsequent neuron, making its role more concrete.
#
# 2.  **Activation Function:**
#     *   Changed "decides whether to pass the signal forward, introducing complexity" to "processes this sum to decide if the neuron should 'fire' and send a signal forward, much like a filter deciding what information is important enough to pass on, allowing the network to learn non-linear, complex relationships."
#     *   Used the common analogy of a neuron "firing."
#     *   Added the "much like a filter deciding what information is important enough to pass on" analogy for better intuition.
#     *   Explicitly stated that it "allowing the network to learn non-linear, complex relationships" which explains *why* the complexity is important without getting too technical.

# %% [markdown]
# ## 6. Style / Format Control

# %%
print('\n=== FORMAT CONTROL ===')
prompt="""Explain Neural Networks with constraints:Audience: 10-year-oldTone: FriendlyFormat: Bullet pointsLength: 6 bullets maxInclude: 1 real-world analogyAvoid: Technical jargon""" # Define the prompt with specific formatting and content constraints
print('Prompt:',prompt)
resp=model.generate_content(prompt) # Generate content adhering to the specified style and format
print(resp.text)
# Out:
# === FORMAT CONTROL ===
# Prompt: Explain Neural Networks with constraints:Audience: 10-year-oldTone: FriendlyFormat: Bullet pointsLength: 6 bullets maxInclude: 1 real-world analogyAvoid: Technical jargon
# Here's an explanation of Neural Networks for a 10-year-old:
#
# *   **Neural Networks** are like super-smart digital brains that computers use to learn new things!
# *   Instead of being told every single rule, they learn by looking at thousands and thousands of examples, just like you do when you're exploring.
# *   **Here's an analogy:** It's like when you're learning to tell the difference between a Red Delicious apple and a Granny Smith apple. At first, you might not know, but after seeing and touching many of each, you learn their distinct colors, shapes, and even how they feel.
# *   A Neural Network does the same! You show it tons of pictures of apples, and it starts to "figure out" the patterns and differences all by itself.
# *   Once it has learned, if you show it a *new* picture of an apple, it can make a really good guess about what kind it is!
# *   These clever learning systems help computers do amazing things, like understanding your voice when you talk to a smart speaker, recommending your favorite videos, or even helping self-driving cars "see" the road.

# %% [markdown]
# ## Bonus — Multilingual Prompting

# %%
print('\n=== MULTILINGUAL (TAMIL) ===')
prompt=f"Explain Neural Networks in Tamil in 4 simple sentences." # Define the prompt to generate content in a specific language
print('Prompt:',prompt)
resp=model.generate_content(prompt) # Generate content in Tamil
print(resp.text)
# Out:
# === MULTILINGUAL (TAMIL) ===
# Prompt: Explain Neural Networks in Tamil in 4 simple sentences.
# நியூரல் நெட்வொர்க்குகள் மனித மூளையின் செயல்பாடுகளால் உத்வேகம் பெற்ற ஒரு செயற்கை நுண்ணறிவு மாதிரி. இது ஒன்றோடொன்று இணைக்கப்பட்ட பல "நியூரன்கள்" அல்லது கணுக்களைக் கொண்டது. தரவுகளிலிருந்து கற்றுக்கொள்ளும் போது, இந்த இணைப்புகளின் வலிமையை சரிசெய்து தகவல்களைப் பதப்படுத்துகிறது. இதன் மூலம் வடிவங்களை அடையாளம் காணவும், கணிப்புகளைச் செய்யவும், சிக்கலான பிரச்சினைகளைத் தீர்க்கவும் இது உதவுகிறது.

# %% [markdown]
# ## Bonus — Length / Compression Control

# %%
print('\n=== LENGTH CONTROL ===')
prompt="""Explain Neural Networks in exactly:(1) One sentence(2) One paragraph(3) One tweet(4) One analogy(5) One exam definition (50 words)""" # Define the prompt with strict length requirements for different formats
print('Prompt:',prompt)
resp=model.generate_content(prompt) # Generate content with precise length control
print(resp.text)
# Out:
# === LENGTH CONTROL ===
# Prompt: Explain Neural Networks in exactly:(1) One sentence(2) One paragraph(3) One tweet(4) One analogy(5) One exam definition (50 words)
# Here are the explanations of Neural Networks in the requested formats:
#
# **(1) One sentence**
# Neural networks are computational models inspired by the human brain, designed to learn complex patterns and relationships from data to perform tasks like classification or prediction.
#
# **(2) One paragraph**
# Neural networks are a powerful subset of machine learning, loosely modeled after the structure and function of the human brain. They consist of interconnected nodes, or "neurons," organized into distinct layers: an input layer, one or more "hidden" layers, and an output layer. Each connection between neurons has a numerical weight, which is adjusted during a training phase as the network processes vast amounts of data. By propagating data through these weighted connections and applying activation functions, neural networks learn to identify intricate patterns, features, and relationships within the data, enabling them to perform complex tasks such as image recognition, natural language processing, and predictive analysis with remarkable accuracy.
#
# **(3) One tweet**
# Neural Networks are AI systems that learn from data like a brain, finding hidden patterns to make smart predictions and decisions. #AI #MachineLearning #DeepLearning
#
# **(4) One analogy**
# Imagine a high-tech sorting facility for objects, but instead of pre-programmed rules, it learns. When an object (data input) arrives, it passes through various stations (layers). Each station has specialized "inspectors" (neurons) that check for specific features (e.g., color, shape, texture). These inspectors then pass their "observations" with varying levels of emphasis (weights) to the next set of inspectors. Over time, as the facility sorts millions of objects and receives feedback on its accuracy, the inspectors learn which features are most important and how to combine their observations to make the best final decision (output), like "this is a cat" or "this is a spam email."
#
# **(5) One exam definition (50 words)**
# Neural networks are computational models inspired by the human brain. They consist of interconnected nodes (neurons) organized into layers, which process input data via adjustable weighted connections and activation functions. By iteratively learning from examples, they recognize complex patterns and relationships to perform tasks like classification, prediction, and feature extraction.

# %% [markdown]
# ## Reflection Questions for Students
# - Which prompt produced the clearest output?
# - Which prompt produced the most structured output?
# - How did the role affect the tone?
# - Did reasoning steps increase clarity?
# - Why are constraints powerful for control?
# - Which output works best for learning?
